# %%
import pandas as pd

# %%
file_path ="/content/hospital-childbirth-1995-2023-supplementary-data-tables-en.xlsx"

# %%
df = pd.read_excel(file_path, sheet_name="Table 1")

df.head()
# Out:
#   Table 1  Inpatient hospitalizations: Volumes and lengths of stay, 1995–1996 to 2023–2024  \
# 0                              Discharge fiscal year
# 1                                          2023–2024
# 2                                          2023–2024
# 3                                          2023–2024
# 4                                          2023–2024
#
#                   Unnamed: 1 Unnamed: 2 Unnamed: 3            Unnamed: 4  \
# 0         Province/territory  Age group        Sex  Number of discharges
# 1  Newfoundland and Labrador      00–04        All                  1011
# 2  Newfoundland and Labrador      00–04     Female                   431
# 3  Newfoundland and Labrador      00–04       Male                   580
# 4  Newfoundland and Labrador      05–09        All                   550
#
#                       Unnamed: 5                       Unnamed: 6
# 0  Total length \nof stay (days)  Average length \nof stay (days)
# 1                           3845                         3.803165
# 2                           1642                         3.809745
# 3                           2203                         3.798276
# 4                           1862                         3.385455

# %%
# Droping the first row which contains header descriptions
df_clean = df.drop(index=0).reset_index(drop=True)

# Renamed columns clearly
df_clean.columns = [
    "Fiscal_Year",
    "Province_Territory",
    "Age_Group",
    "Sex",
    "Number_of_Discharges",
    "Total_Length_of_Stay_Days",
    "Average_Length_of_Stay_Days"
]

# Remove rows with notes or missing provinces
df_clean = df_clean[~df_clean["Province_Territory"].isna()]

# Convert numeric columns
numeric_cols = [
    "Number_of_Discharges",
    "Total_Length_of_Stay_Days",
    "Average_Length_of_Stay_Days"
]

for col in numeric_cols:
    df_clean[col] = pd.to_numeric(df_clean[col], errors="coerce")

df_clean.head()
# Out:
#   Fiscal_Year         Province_Territory Age_Group     Sex  \
# 0   2023–2024  Newfoundland and Labrador     00–04     All
# 1   2023–2024  Newfoundland and Labrador     00–04  Female
# 2   2023–2024  Newfoundland and Labrador     00–04    Male
# 3   2023–2024  Newfoundland and Labrador     05–09     All
# 4   2023–2024  Newfoundland and Labrador     05–09  Female
#
#    Number_of_Discharges  Total_Length_of_Stay_Days  \
# 0                1011.0                     3845.0
# 1                 431.0                     1642.0
# 2                 580.0                     2203.0
# 3                 550.0                     1862.0
# 4                 236.0                      712.0
#
#    Average_Length_of_Stay_Days
# 0                     3.803165
# 1                     3.809745
# 2                     3.798276
# 3                     3.385455
# 4                     3.016949

# %%
# Remove rows with notes or missing provinces
df_clean = df_clean[~df_clean["Province_Territory"].isna()]

# %%
# Convert numeric columns
numeric_cols = [
    "Number_of_Discharges",
    "Total_Length_of_Stay_Days",
    "Average_Length_of_Stay_Days"
]

for col in numeric_cols:
    df_clean[col] = pd.to_numeric(df_clean[col], errors="coerce")

df_clean.head()
# Out:
#   Fiscal_Year         Province_Territory Age_Group     Sex  \
# 0   2023–2024  Newfoundland and Labrador     00–04     All
# 1   2023–2024  Newfoundland and Labrador     00–04  Female
# 2   2023–2024  Newfoundland and Labrador     00–04    Male
# 3   2023–2024  Newfoundland and Labrador     05–09     All
# 4   2023–2024  Newfoundland and Labrador     05–09  Female
#
#    Number_of_Discharges  Total_Length_of_Stay_Days  \
# 0                1011.0                     3845.0
# 1                 431.0                     1642.0
# 2                 580.0                     2203.0
# 3                 550.0                     1862.0
# 4                 236.0                      712.0
#
#    Average_Length_of_Stay_Days
# 0                     3.803165
# 1                     3.809745
# 2                     3.798276
# 3                     3.385455
# 4                     3.016949

# %%
# Remove footnotes rows if any appear later
df_clean = df_clean[~df_clean["Age_Group"].astype(str).str.contains("Note", case=False, na=False)]

# Save cleaned dataset
output_path = "/content/canada_hospital_inpatient_clean_1995_2024.csv"
df_clean.to_csv(output_path, index=False)

output_path
# Out:
# '/content/canada_hospital_inpatient_clean_1995_2024.csv'
